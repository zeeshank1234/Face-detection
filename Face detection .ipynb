# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshank1234/Face-detection/blob/main/Face%20detection%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/data/image
# Out:
# origin.7z.001  origin.7z.003  origin.7z.005  origin.7z.007
# origin.7z.002  origin.7z.004  origin.7z.006  origin.7z.008

# %%
!7za -y x "/content/drive/MyDrive/Colab Notebooks/data/image/origin.7z.*"
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 8 files, 8113576419 bytes (7738 MiB)
#   0%
# Extracting archive: /content/drive/MyDrive/Colab Notebooks/data/image/origin.7z.001
# --
# Path = /content/drive/MyDrive/Colab Notebooks/data/image/origin.7z.001
# Type = Split
# Physical Size = 1048576000
# Volumes = 8
# Total Physical Size = 8113576419
# ----
# Path = origin.7z
# Size = 8113576419
# --
# Path = origin.7z
# Type = 7z
# Physical Size = 8113576419
# Headers Size = 863607
# Method = LZMA:25
# Solid = +
# Blocks = 2
#
#   1% 1659 - origin/amazed_american_662.jpg

# %%
# !cp -r ./origin "/content/drive/MyDrive/Colab Notebooks"

# %%
label_file_path =r"/content/drive/MyDrive/Colab Notebooks/data/label/label.lst"
images_file_name =r"/content/drive/MyDrive/Colab Notebooks/origin"

# %%
from os.path import split
import pandas as pd
df_info = pd.read_csv(label_file_path , sep=" " , header=None)
col_names ="image_name face_id_in_image face_box_top face_box_left face_box_right face_box_bottom face_box_cofidence expression_label".split(" ")
df_info.columns = col_names

df_info.head()
# Out:
#             image_name  face_id_in_image  face_box_top  face_box_left  \
# 0  angry_actor_104.jpg                 0            28            113
# 1  angry_actor_109.jpg                 0            31            157
# 2  angry_actor_120.jpg                 1            53             53
# 3   angry_actor_13.jpg                 0            77             51
# 4  angry_actor_132.jpg                 0            95             31
#
#    face_box_right  face_box_bottom  face_box_cofidence  expression_label
# 0             226              141             22.9362                 0
# 1             345              219             50.3056                 0
# 2             372              372             13.9434                 2
# 3             362              388             85.8104                 3
# 4             412              476             82.3948                 0

# %%
df_info.shape
# Out:
# (91793, 8)

# %%
df_sel = df_info[df_info.face_box_cofidence >35]
df_sel
# Out:
#                          image_name  face_id_in_image  face_box_top  \
# 1               angry_actor_109.jpg                 0            31
# 3                angry_actor_13.jpg                 0            77
# 4               angry_actor_132.jpg                 0            95
# 5               angry_actor_137.jpg                 0            93
# 7                angry_actor_14.jpg                 0            13
# ...                             ...               ...           ...
# 91788  surprised_expression_546.jpg                 0            70
# 91789  surprised_expression_381.jpg                 0            51
# 91790  surprised_expression_395.jpg                 0            27
# 91791         ecstatic_asian_31.jpg                 0            60
# 91792  surprised_expression_394.jpg                 0            47
#
#        face_box_left  face_box_right  face_box_bottom  face_box_cofidence  \
# 1                157             345              219             50.3056
# ...

# %%
import cv2
all_images =[]
all_labels =[]

# %%
import os
img_path = "/content/drive/MyDrive/Colab Notebooks/origin"
for i, row in df_info.iterrows():
    img_name = row["image_name"]
    cmb_filename = os.path.join(img_path, img_name)
    read_img =cv2.imread(cmb_filename)


    if read_img is not None:
      x1 = row["face_box_left"]
      y1 = row["face_box_top"]
      x2 = row["face_box_right"]
      y2 = row["face_box_bottom"]
      crop_imgs =read_img[y1:y2,x1:x2]
      label = row["expression_label"]

    else:
        print(f"ERROR LOADING images{img_name}")
# Out:
# ERROR LOADING imagesangry_actor_104.jpg
# ERROR LOADING imagesangry_actor_109.jpg
# ERROR LOADING imagesangry_actor_120.jpg
# ERROR LOADING imagesangry_actor_13.jpg

# %%
preprocessed_images = []
labels = []
def preprocess_image(image_path, x1, y1, x2, y2):
  import os
  image = cv2.imread(os.path.join(data_path, image_path))
  target_size = (224, 224)
  image = cv2.resize(image, target_size)
  roi = row[y1:y2, x1:x2]
  return roi
  preprocessed_images.append(roi)
  labels.append(label)

# %%
import numpy as np
preprocessed_images = np.array(preprocessed_images)
labels = np.array(labels)
